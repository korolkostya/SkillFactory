# %% [markdown]
# Суть проекта — отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import combinations
from scipy.stats import ttest_ind

# %%
# %matplotlib inline

# %%
pd.set_option('display.max_columns', 50)

# %%
# Функции
# Функция получения подробной информации о каждом столбце
def get_unique_and_isnull(df):
    for col in list(df.columns):
        print(col)
        print(df[col].unique())
        print(df[col].value_counts())
        print('Пустых значений:')
        print(df[col].isnull().sum())
        print('Уникальных значений:')
        print(df[col].nunique())
        print()

# Функция построения графиков boxplot по списку


def get_boxplot(column):
    fig, ax = plt.subplots(figsize=(12, 4))
    sns.boxplot(x=column, y='score',
                data=students.loc[students.loc[:, column].isin(
                    students.loc[:, column].value_counts().index[:5])],
                ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# Функция нахождения значимых параметров с использованием теста Стьюдента


def get_stat_dif(column):
    cols = students.loc[:, column].value_counts().index[:5]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(students.loc[students.loc[:, column] == comb[0], 'score'],
                     students.loc[students.loc[:, column] == comb[1], 'score']).pvalue \
                <= 0.05/len(combinations_all):  # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
students = pd.read_csv('stud_math.xls')
students.info
# Out:
# <bound method DataFrame.info of     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother         2.0        2.0       0.0       yes     no   no
# 1    course   father         1.0        2.0       0.0        no    yes   no
# 2     other   mother         1.0        2.0       3.0       yes     no  NaN
# 3      home   mother         1.0        3.0       0.0        no    yes  yes
# 4      home   father         1.0        2.0       0.0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
# 391  course   mother         2.0        1.0       0.0        no     no   no
# 392  course      NaN         1.0        1.0       3.0       NaN     no   no
# 393  course   mother         3.0        1.0       0.0        no     no   no
# 394     NaN   father         1.0        1.0       0.0       NaN     no   no
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 0           no     yes                 -6.0    yes      NaN       no     4.0
# 1           no      no                 -6.0    yes      yes       no     5.0
# 2           no     yes                 -6.0    yes      yes      NaN     4.0
# 3          yes     yes                 -9.0    yes      yes      yes     3.0
# 4           no     yes                 -6.0    yes       no       no     4.0
# ..         ...     ...                  ...    ...      ...      ...     ...
# 390         no     yes                 -6.0    yes       no       no     5.0
# 391         no      no                 -3.0    yes      yes       no     2.0
# 392         no      no                 -3.0    NaN       no       no     5.0
# 393        NaN      no                 -3.0    yes      yes       no     4.0
# 394         no     yes                 -3.0    yes      yes       no     3.0
#
#      freetime  goout  health  absences  score
# 0         3.0    4.0     3.0       6.0   30.0
# 1         3.0    3.0     3.0       4.0   30.0
# 2         3.0    2.0     3.0      10.0   50.0
# 3         2.0    2.0     5.0       2.0   75.0
# 4         3.0    2.0     5.0       4.0   50.0
# ..        ...    ...     ...       ...    ...
# 390       5.0    4.0     4.0     212.0   45.0
# 391       4.0    5.0     2.0       3.0   80.0
# 392       5.0    3.0     3.0       3.0   35.0
# 393       4.0    1.0     5.0       0.0   50.0
# 394       2.0    3.0     5.0       5.0   45.0
#
# [395 rows x 30 columns]>

# %%
students
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother         2.0        2.0       0.0       yes     no   no
# 1    course   father         1.0        2.0       0.0        no    yes   no
# 2     other   mother         1.0        2.0       3.0       yes     no  NaN
# 3      home   mother         1.0        3.0       0.0        no    yes  yes
# 4      home   father         1.0        2.0       0.0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
# 391  course   mother         2.0        1.0       0.0        no     no   no
# 392  course      NaN         1.0        1.0       3.0       NaN     no   no
# 393  course   mother         3.0        1.0       0.0        no     no   no
# 394     NaN   father         1.0        1.0       0.0       NaN     no   no
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 0           no     yes                 -6.0    yes      NaN       no     4.0
# 1           no      no                 -6.0    yes      yes       no     5.0
# 2           no     yes                 -6.0    yes      yes      NaN     4.0
# 3          yes     yes                 -9.0    yes      yes      yes     3.0
# 4           no     yes                 -6.0    yes       no       no     4.0
# ..         ...     ...                  ...    ...      ...      ...     ...
# 390         no     yes                 -6.0    yes       no       no     5.0
# 391         no      no                 -3.0    yes      yes       no     2.0
# 392         no      no                 -3.0    NaN       no       no     5.0
# 393        NaN      no                 -3.0    yes      yes       no     4.0
# 394         no     yes                 -3.0    yes      yes       no     3.0
#
#      freetime  goout  health  absences  score
# 0         3.0    4.0     3.0       6.0   30.0
# 1         3.0    3.0     3.0       4.0   30.0
# 2         3.0    2.0     3.0      10.0   50.0
# 3         2.0    2.0     5.0       2.0   75.0
# 4         3.0    2.0     5.0       4.0   50.0
# ..        ...    ...     ...       ...    ...
# 390       5.0    4.0     4.0     212.0   45.0
# 391       4.0    5.0     2.0       3.0   80.0
# 392       5.0    3.0     3.0       3.0   35.0
# 393       4.0    1.0     5.0       0.0   50.0
# 394       2.0    3.0     5.0       5.0   45.0
#
# [395 rows x 30 columns]

# %% [markdown]
# Переименуем колонки для удобства использования

# %%
students.rename(columns={'Pstatus': 'pstatus', 'Medu': 'medu',
                'Fedu': 'fedu', 'Mjob': 'mjob', 'Fjob': 'fjob'}, inplace=True)

# %%
students.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'pstatus', 'medu', 'fedu',
#        'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'studytime, granular', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'health', 'absences', 'score'],
#       dtype='object')

# %%
students.dtypes
# Out:
# school                  object
# sex                     object
# age                      int64
# address                 object
# famsize                 object
# pstatus                 object
# medu                   float64
# fedu                   float64
# mjob                    object
# fjob                    object
# reason                  object
# guardian                object
# traveltime             float64
# studytime              float64
# failures               float64
# schoolsup               object
# famsup                  object
# paid                    object
# activities              object
# nursery                 object
# studytime, granular    float64
# higher                  object
# internet                object
# romantic                object
# famrel                 float64
# freetime               float64
# goout                  float64
# health                 float64
# absences               float64
# score                  float64
# dtype: object

# %%
students.isnull().sum()
# Out:
# school                  0
# sex                     0
# age                     0
# address                17
# famsize                27
# pstatus                45
# medu                    3
# fedu                   24
# mjob                   19
# fjob                   36
# reason                 17
# guardian               31
# traveltime             28
# studytime               7
# failures               22
# schoolsup               9
# famsup                 39
# paid                   40
# activities             14
# nursery                16
# studytime, granular     7
# higher                 20
# internet               34
# romantic               31
# famrel                 27
# freetime               11
# goout                   8
# health                 15
# absences               12
# score                   6
# dtype: int64

# %% [markdown]
# Если удалить все строки с пустыми значениями, то будет значительная потеря данных.
# Значит продолжим работать с пустыми полями.
# Единственное сразу удалим строки, где есть пустые значения в столбце оценок за экзамен.

# %%
students = students.loc[students.score.isnull() != True]
students
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A   2.0   2.0  services  services
# 391     MS   M   17       U     LE3       T   3.0   1.0  services  services
# 392     MS   M   21       R     GT3       T   1.0   1.0     other     other
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
# 394     MS   M   19       U     LE3       T   1.0   1.0     other   at_home
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother         2.0        2.0       0.0       yes     no   no
# 1    course   father         1.0        2.0       0.0        no    yes   no
# 2     other   mother         1.0        2.0       3.0       yes     no  NaN
# 3      home   mother         1.0        3.0       0.0        no    yes  yes
# 4      home   father         1.0        2.0       0.0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 390  course      NaN         1.0        2.0       2.0        no    yes  yes
# 391  course   mother         2.0        1.0       0.0        no     no   no
# 392  course      NaN         1.0        1.0       3.0       NaN     no   no
# 393  course   mother         3.0        1.0       0.0        no     no   no
# 394     NaN   father         1.0        1.0       0.0       NaN     no   no
#
#     activities nursery  studytime, granular higher internet romantic  famrel  \
# 0           no     yes                 -6.0    yes      NaN       no     4.0
# 1           no      no                 -6.0    yes      yes       no     5.0
# 2           no     yes                 -6.0    yes      yes      NaN     4.0
# 3          yes     yes                 -9.0    yes      yes      yes     3.0
# 4           no     yes                 -6.0    yes       no       no     4.0
# ..         ...     ...                  ...    ...      ...      ...     ...
# 390         no     yes                 -6.0    yes       no       no     5.0
# 391         no      no                 -3.0    yes      yes       no     2.0
# 392         no      no                 -3.0    NaN       no       no     5.0
# 393        NaN      no                 -3.0    yes      yes       no     4.0
# 394         no     yes                 -3.0    yes      yes       no     3.0
#
#      freetime  goout  health  absences  score
# 0         3.0    4.0     3.0       6.0   30.0
# 1         3.0    3.0     3.0       4.0   30.0
# 2         3.0    2.0     3.0      10.0   50.0
# 3         2.0    2.0     5.0       2.0   75.0
# 4         3.0    2.0     5.0       4.0   50.0
# ..        ...    ...     ...       ...    ...
# 390       5.0    4.0     4.0     212.0   45.0
# 391       4.0    5.0     2.0       3.0   80.0
# 392       5.0    3.0     3.0       3.0   35.0
# 393       4.0    1.0     5.0       0.0   50.0
# 394       2.0    3.0     5.0       5.0   45.0
#
# [389 rows x 30 columns]

# %%
get_unique_and_isnull(students)
# Out:
# school
# ['GP' 'MS']
# GP    344
# MS     45
# Name: school, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# sex
# ['F' 'M']
# F    204
# M    185
# Name: sex, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# age
# [18 17 15 16 19 22 20 21]
# 16    103
# 17     98
# 15     82
# 18     80
# 19     21
# 20      3
# 21      1
# 22      1
# Name: age, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 8
#
# address
# ['U' nan 'R']
# U    291
# R     83
# Name: address, dtype: int64
# Пустых значений:
# 15
# Уникальных значений:
# 2
#
# famsize
# [nan 'GT3' 'LE3']
# GT3    255
# LE3    107
# Name: famsize, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 2
#
# pstatus
# ['A' nan 'T']
# T    308
# A     36
# Name: pstatus, dtype: int64
# Пустых значений:
# 45
# Уникальных значений:
# 2
#
# medu
# [ 4.  1.  3.  2. nan  0.]
# 4.0    131
# 2.0    100
# 3.0     96
# 1.0     56
# 0.0      3
# Name: medu, dtype: int64
# Пустых значений:
# 3
# Уникальных значений:
# 5
#
# fedu
# [ 4.  1.  2.  3. 40. nan  0.]
# 2.0     105
# 3.0      94
# 4.0      88
# 1.0      75
# 0.0       2
# 40.0      1
# Name: fedu, dtype: int64
# Пустых значений:
# 24
# Уникальных значений:
# 6
#
# mjob
# ['at_home' 'health' 'other' 'services' 'teacher' nan]
# other       127
# services     98
# at_home      58
# teacher      55
# health       32
# Name: mjob, dtype: int64
# Пустых значений:
# 19
# Уникальных значений:
# 5
#
# fjob
# ['teacher' 'other' nan 'health' 'services' 'at_home']
# other       194
# services     99
# teacher      29
# at_home      16
# health       15
# Name: fjob, dtype: int64
# Пустых значений:
# 36
# Уникальных значений:
# 5
#
# reason
# ['course' 'other' 'home' 'reputation' nan]
# course        135
# reputation    102
# home          101
# other          34
# Name: reason, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# guardian
# ['mother' 'father' 'other' nan]
# mother    248
# father     86
# other      24
# Name: guardian, dtype: int64
# Пустых значений:
# 31
# Уникальных значений:
# 3
#
# traveltime
# [ 2.  1.  3. nan  4.]
# 1.0    239
# 2.0     94
# 3.0     21
# 4.0      7
# Name: traveltime, dtype: int64
# Пустых значений:
# 28
# Уникальных значений:
# 4
#
# studytime
# [ 2.  3.  1. nan  4.]
# 2.0    189
# 1.0    103
# 3.0     63
# 4.0     27
# Name: studytime, dtype: int64
# Пустых значений:
# 7
# Уникальных значений:
# 4
#
# failures
# [ 0.  3. nan  2.  1.]
# 0.0    290
# 1.0     48
# 2.0     15
# 3.0     14
# Name: failures, dtype: int64
# Пустых значений:
# 22
# Уникальных значений:
# 4
#
# schoolsup
# ['yes' 'no' nan]
# no     331
# yes     49
# Name: schoolsup, dtype: int64
# Пустых значений:
# 9
# Уникальных значений:
# 2
#
# famsup
# ['no' 'yes' nan]
# yes    216
# no     135
# Name: famsup, dtype: int64
# Пустых значений:
# 38
# Уникальных значений:
# 2
#
# paid
# ['no' nan 'yes']
# no     197
# yes    153
# Name: paid, dtype: int64
# Пустых значений:
# 39
# Уникальных значений:
# 2
#
# activities
# ['no' 'yes' nan]
# yes    192
# no     183
# Name: activities, dtype: int64
# Пустых значений:
# 14
# Уникальных значений:
# 2
#
# nursery
# ['yes' 'no' nan]
# yes    297
# no      77
# Name: nursery, dtype: int64
# Пустых значений:
# 15
# Уникальных значений:
# 2
#
# studytime, granular
# [ -6.  -9.  -3.  nan -12.]
# -6.0     189
# -3.0     103
# -9.0      63
# -12.0     27
# Name: studytime, granular, dtype: int64
# Пустых значений:
# 7
# Уникальных значений:
# 4
#
# higher
# ['yes' nan 'no']
# yes    350
# no      19
# Name: higher, dtype: int64
# Пустых значений:
# 20
# Уникальных значений:
# 2
#
# internet
# [nan 'yes' 'no']
# yes    300
# no      55
# Name: internet, dtype: int64
# Пустых значений:
# 34
# Уникальных значений:
# 2
#
# romantic
# ['no' nan 'yes']
# no     235
# yes    123
# Name: romantic, dtype: int64
# Пустых значений:
# 31
# Уникальных значений:
# 2
#
# famrel
# [ 4.  5.  3. nan -1.  2.  1.]
#  4.0    178
#  5.0     97
#  3.0     62
#  2.0     17
#  1.0      7
# -1.0      1
# Name: famrel, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 6
#
# freetime
# [ 3.  2.  4.  1.  5. nan]
# 3.0    152
# 4.0    110
# 2.0     63
# 5.0     37
# 1.0     18
# Name: freetime, dtype: int64
# Пустых значений:
# 9
# Уникальных значений:
# 5
#
# goout
# [ 4.  3.  2.  1.  5. nan]
# 3.0    126
# 2.0    101
# 4.0     81
# 5.0     51
# 1.0     23
# Name: goout, dtype: int64
# Пустых значений:
# 7
# Уникальных значений:
# 5
#
# health
# [ 3.  5.  1.  2.  4. nan]
# 5.0    137
# 3.0     88
# 4.0     60
# 1.0     47
# 2.0     42
# Name: health, dtype: int64
# Пустых значений:
# 15
# Уникальных значений:
# 5
#
# absences
# [  6.   4.  10.   2.   0.  16.  nan  14.   7.   8.  25.  12.  54.  18.
#   26.  20.  56.  24.  28.   5.  13.  15.  22.   3. 385.  21.   1.  75.
#   30.  19.   9.  11.  38.  40.  23.  17. 212.]
# 0.0      110
# 2.0       60
# 4.0       52
# 6.0       30
# 8.0       20
# 10.0      17
# 14.0      12
# 12.0      12
# 16.0       7
# 3.0        7
# 7.0        6
# 18.0       5
# 5.0        5
# 20.0       4
# 9.0        3
# 22.0       3
# 1.0        3
# 13.0       2
# 15.0       2
# 11.0       2
# 40.0       1
# 38.0       1
# 56.0       1
# 23.0       1
# 24.0       1
# 25.0       1
# 385.0      1
# 17.0       1
# 75.0       1
# 21.0       1
# 212.0      1
# 28.0       1
# 19.0       1
# 26.0       1
# 30.0       1
# 54.0       1
# Name: absences, dtype: int64
# Пустых значений:
# 11
# Уникальных значений:
# 36
#
# score
# [ 30.  50.  75.  55.  95.  45.  60.  70.  80.  25.  40.  85.  90.  65.
#  100.  35.   0.  20.]
# 50.0     54
# 55.0     46
# 0.0      37
# 75.0     33
# 65.0     31
# 60.0     31
# 40.0     31
# 45.0     27
# 70.0     27
# 80.0     16
# 30.0     15
# 90.0     12
# 35.0      9
# 25.0      7
# 85.0      6
# 95.0      5
# 20.0      1
# 100.0     1
# Name: score, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 18

# %% [markdown]
# # Работа с числовыми переменными

# %% [markdown]
# По результатам выполнения прошлой функции видно, что с колонками 'studytime', 'failures', 'studytime, granular', 'freetime', 'goout', 'health' в целом все нормально.

# %% [markdown]
# Для дальнешего построения и использования модели необходимо избавиться от значений, которых малое количество.
# Поэтому для столбцов:
# 'age' - удалим строки с даннми >=20
# 'medu' - удалим строки с 0.0
# 'fedu' - удалим стоки с 0.0 и исправим опечатку с 40.0 на 4.0
# 'traveltime' - удалим строки со значением 4.0
# 'famrel' - вероятно там опечатка, можем исправить с -1.0 на 1.0, но все равно будет мало данных для значений с 1.0, поэтому удалим строки с 1.0 и -1.0
# 'absences' - в дальнейшем будем использовать только значения у которых количество повторений >10
# 'score' - в дальнейшем будем использовать только значения у которых количество повторений >10

# %%
students = students.loc[students.age < 20]
students = students.loc[students.medu != 0.0]
students.loc[(students.fedu == 40.0), 'fedu'] = 4.0
students = students.loc[students.fedu != 0.0]
students = students.loc[students.traveltime != 4.0]
students.loc[(students.famrel == -1.0), 'famrel'] = 1.0
students = students.loc[students.famrel != 1.0]
students = students.loc[(students.absences == 0.0) | (students.absences == 2.0) | (students.absences == 4.0) |
                        (students.absences == 6.0) | (students.absences == 8.0) | (students.absences == 10.0) |
                        (students.absences == 12.0) | (students.absences == 14.0)]
students = students.loc[(students.score == 50.0) | (students.score == 55.0) | (students.score == 0.0) |
                        (students.score == 75.0) | (students.score == 65.0) | (students.score == 60.0) |
                        (students.score == 40.0) | (students.score == 45.0) | (students.score == 70.0) |
                        (students.score == 80.0) | (students.score == 30.0) | (students.score == 90.0)]

# %% [markdown]
# # Не получилось выбрать данные адекватным способом, где повторение элемента >10 раз
#   # Как это сделать?

# %%
#students.loc[students.absences.value_counts() > 10]

# %%
get_unique_and_isnull(students)
# Out:
# school
# ['GP' 'MS']
# GP    248
# MS     29
# Name: school, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# sex
# ['F' 'M']
# F    150
# M    127
# Name: sex, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# age
# [18 17 15 16 19]
# 16    80
# 15    68
# 17    67
# 18    49
# 19    13
# Name: age, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 5
#
# address
# ['U' nan 'R']
# U    211
# R     53
# Name: address, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 2
#
# famsize
# [nan 'GT3' 'LE3']
# GT3    184
# LE3     75
# Name: famsize, dtype: int64
# Пустых значений:
# 18
# Уникальных значений:
# 2
#
# pstatus
# ['A' nan 'T']
# T    225
# A     22
# Name: pstatus, dtype: int64
# Пустых значений:
# 30
# Уникальных значений:
# 2
#
# medu
# [ 4.  1.  3.  2. nan]
# 4.0    93
# 2.0    79
# 3.0    63
# 1.0    39
# Name: medu, dtype: int64
# Пустых значений:
# 3
# Уникальных значений:
# 4
#
# fedu
# [ 4.  1.  2.  3. nan]
# 2.0    78
# 3.0    73
# 4.0    58
# 1.0    51
# Name: fedu, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# mjob
# ['at_home' 'health' 'other' 'services' 'teacher' nan]
# other       89
# services    63
# at_home     43
# teacher     39
# health      28
# Name: mjob, dtype: int64
# Пустых значений:
# 15
# Уникальных значений:
# 5
#
# fjob
# ['teacher' 'other' nan 'health' 'services' 'at_home']
# other       139
# services     72
# teacher      19
# at_home      12
# health       11
# Name: fjob, dtype: int64
# Пустых значений:
# 24
# Уникальных значений:
# 5
#
# reason
# ['course' 'other' 'home' 'reputation' nan]
# course        96
# home          73
# reputation    72
# other         22
# Name: reason, dtype: int64
# Пустых значений:
# 14
# Уникальных значений:
# 4
#
# guardian
# ['mother' 'father' 'other' nan]
# mother    166
# father     70
# other      16
# Name: guardian, dtype: int64
# Пустых значений:
# 25
# Уникальных значений:
# 3
#
# traveltime
# [ 2.  1.  3. nan]
# 1.0    167
# 2.0     70
# 3.0     17
# Name: traveltime, dtype: int64
# Пустых значений:
# 23
# Уникальных значений:
# 3
#
# studytime
# [ 2.  3.  1. nan  4.]
# 2.0    141
# 1.0     68
# 3.0     42
# 4.0     21
# Name: studytime, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 4
#
# failures
# [ 0.  3. nan  1.  2.]
# 0.0    216
# 1.0     29
# 2.0      9
# 3.0      6
# Name: failures, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# schoolsup
# ['yes' 'no' nan]
# no     235
# yes     37
# Name: schoolsup, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 2
#
# famsup
# ['no' 'yes' nan]
# yes    155
# no      96
# Name: famsup, dtype: int64
# Пустых значений:
# 26
# Уникальных значений:
# 2
#
# paid
# ['no' nan 'yes']
# no     136
# yes    112
# Name: paid, dtype: int64
# Пустых значений:
# 29
# Уникальных значений:
# 2
#
# activities
# ['no' 'yes' nan]
# yes    140
# no     124
# Name: activities, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 2
#
# nursery
# ['yes' 'no' nan]
# yes    209
# no      54
# Name: nursery, dtype: int64
# Пустых значений:
# 14
# Уникальных значений:
# 2
#
# studytime, granular
# [ -6.  -9.  -3.  nan -12.]
# -6.0     141
# -3.0      68
# -9.0      42
# -12.0     21
# Name: studytime, granular, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 4
#
# higher
# ['yes' nan 'no']
# yes    255
# no      10
# Name: higher, dtype: int64
# Пустых значений:
# 12
# Уникальных значений:
# 2
#
# internet
# [nan 'yes' 'no']
# yes    207
# no      43
# Name: internet, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 2
#
# romantic
# ['no' nan 'yes']
# no     170
# yes     80
# Name: romantic, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 2
#
# famrel
# [ 4.  5.  3. nan  2.]
# 4.0    133
# 5.0     72
# 3.0     45
# 2.0     10
# Name: famrel, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# freetime
# [ 3.  2.  4.  1.  5. nan]
# 3.0    117
# 4.0     73
# 2.0     47
# 5.0     23
# 1.0     13
# Name: freetime, dtype: int64
# Пустых значений:
# 4
# Уникальных значений:
# 5
#
# goout
# [ 4.  3.  2.  1.  5. nan]
# 3.0    90
# 2.0    73
# 4.0    60
# 5.0    32
# 1.0    17
# Name: goout, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 5
#
# health
# [ 3.  5.  1.  2.  4. nan]
# 5.0    98
# 3.0    61
# 4.0    44
# 2.0    32
# 1.0    29
# Name: health, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 5
#
# absences
# [ 6.  4. 10.  2.  0.  8. 14. 12.]
# 0.0     100
# 2.0      54
# 4.0      49
# 6.0      25
# 8.0      17
# 10.0     15
# 12.0     11
# 14.0      6
# Name: absences, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 8
#
# score
# [30. 50. 75. 55. 45. 60. 70. 80. 90. 65. 40.  0.]
# 50.0    46
# 0.0     35
# 55.0    35
# 70.0    25
# 65.0    24
# 75.0    23
# 60.0    22
# 40.0    19
# 45.0    18
# 30.0    11
# 80.0    11
# 90.0     8
# Name: score, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 12

# %% [markdown]
# А в колонке 'absences' мало повторений значений 14 и нет пустых значений, удалим строки с эти значением.
# Теперь в колонке 'failures' мало повторений значений 2.0 и 3.0, будем заполнять ими пустые значения.

# %%
students = students.loc[(students.absences != 14.0)]

# %%
get_unique_and_isnull(students)
# Out:
# school
# ['GP' 'MS']
# GP    242
# MS     29
# Name: school, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# sex
# ['F' 'M']
# F    146
# M    125
# Name: sex, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 2
#
# age
# [18 17 15 16 19]
# 16    79
# 15    68
# 17    64
# 18    48
# 19    12
# Name: age, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 5
#
# address
# ['U' nan 'R']
# U    205
# R     53
# Name: address, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 2
#
# famsize
# [nan 'GT3' 'LE3']
# GT3    182
# LE3     71
# Name: famsize, dtype: int64
# Пустых значений:
# 18
# Уникальных значений:
# 2
#
# pstatus
# ['A' nan 'T']
# T    220
# A     21
# Name: pstatus, dtype: int64
# Пустых значений:
# 30
# Уникальных значений:
# 2
#
# medu
# [ 4.  1.  3.  2. nan]
# 4.0    89
# 2.0    78
# 3.0    63
# 1.0    38
# Name: medu, dtype: int64
# Пустых значений:
# 3
# Уникальных значений:
# 4
#
# fedu
# [ 4.  1.  2.  3. nan]
# 2.0    77
# 3.0    71
# 4.0    57
# 1.0    50
# Name: fedu, dtype: int64
# Пустых значений:
# 16
# Уникальных значений:
# 4
#
# mjob
# ['at_home' 'health' 'other' 'services' 'teacher' nan]
# other       88
# services    63
# at_home     42
# teacher     38
# health      25
# Name: mjob, dtype: int64
# Пустых значений:
# 15
# Уникальных значений:
# 5
#
# fjob
# ['teacher' 'other' nan 'health' 'services' 'at_home']
# other       136
# services     72
# teacher      18
# at_home      12
# health       10
# Name: fjob, dtype: int64
# Пустых значений:
# 23
# Уникальных значений:
# 5
#
# reason
# ['course' 'other' 'home' 'reputation' nan]
# course        94
# home          71
# reputation    70
# other         22
# Name: reason, dtype: int64
# Пустых значений:
# 14
# Уникальных значений:
# 4
#
# guardian
# ['mother' 'father' 'other' nan]
# mother    164
# father     68
# other      15
# Name: guardian, dtype: int64
# Пустых значений:
# 24
# Уникальных значений:
# 3
#
# traveltime
# [ 2.  1.  3. nan]
# 1.0    163
# 2.0     68
# 3.0     17
# Name: traveltime, dtype: int64
# Пустых значений:
# 23
# Уникальных значений:
# 3
#
# studytime
# [ 2.  3.  1. nan  4.]
# 2.0    136
# 1.0     68
# 3.0     42
# 4.0     21
# Name: studytime, dtype: int64
# Пустых значений:
# 4
# Уникальных значений:
# 4
#
# failures
# [ 0.  3. nan  1.  2.]
# 0.0    212
# 1.0     28
# 2.0      8
# 3.0      6
# Name: failures, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# schoolsup
# ['yes' 'no' nan]
# no     231
# yes     35
# Name: schoolsup, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 2
#
# famsup
# ['no' 'yes' nan]
# yes    154
# no      92
# Name: famsup, dtype: int64
# Пустых значений:
# 25
# Уникальных значений:
# 2
#
# paid
# ['no' nan 'yes']
# no     130
# yes    112
# Name: paid, dtype: int64
# Пустых значений:
# 29
# Уникальных значений:
# 2
#
# activities
# ['no' 'yes' nan]
# yes    137
# no     122
# Name: activities, dtype: int64
# Пустых значений:
# 12
# Уникальных значений:
# 2
#
# nursery
# ['yes' 'no' nan]
# yes    205
# no      53
# Name: nursery, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 2
#
# studytime, granular
# [ -6.  -9.  -3.  nan -12.]
# -6.0     136
# -3.0      68
# -9.0      42
# -12.0     21
# Name: studytime, granular, dtype: int64
# Пустых значений:
# 4
# Уникальных значений:
# 4
#
# higher
# ['yes' nan 'no']
# yes    249
# no      10
# Name: higher, dtype: int64
# Пустых значений:
# 12
# Уникальных значений:
# 2
#
# internet
# [nan 'yes' 'no']
# yes    201
# no      43
# Name: internet, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 2
#
# romantic
# ['no' nan 'yes']
# no     169
# yes     75
# Name: romantic, dtype: int64
# Пустых значений:
# 27
# Уникальных значений:
# 2
#
# famrel
# [ 4.  5.  3. nan  2.]
# 4.0    129
# 5.0     72
# 3.0     44
# 2.0      9
# Name: famrel, dtype: int64
# Пустых значений:
# 17
# Уникальных значений:
# 4
#
# freetime
# [ 3.  2.  4.  1.  5. nan]
# 3.0    116
# 4.0     73
# 2.0     45
# 5.0     21
# 1.0     13
# Name: freetime, dtype: int64
# Пустых значений:
# 3
# Уникальных значений:
# 5
#
# goout
# [ 4.  3.  2.  1.  5. nan]
# 3.0    88
# 2.0    72
# 4.0    59
# 5.0    30
# 1.0    17
# Name: goout, dtype: int64
# Пустых значений:
# 5
# Уникальных значений:
# 5
#
# health
# [ 3.  5.  1.  2.  4. nan]
# 5.0    96
# 3.0    59
# 4.0    43
# 2.0    31
# 1.0    29
# Name: health, dtype: int64
# Пустых значений:
# 13
# Уникальных значений:
# 5
#
# absences
# [ 6.  4. 10.  2.  0.  8. 12.]
# 0.0     100
# 2.0      54
# 4.0      49
# 6.0      25
# 8.0      17
# 10.0     15
# 12.0     11
# Name: absences, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 7
#
# score
# [30. 50. 75. 55. 45. 60. 70. 80. 90. 65. 40.  0.]
# 50.0    46
# 0.0     35
# 55.0    34
# 70.0    24
# 75.0    23
# 65.0    23
# 60.0    21
# 40.0    19
# 45.0    16
# 30.0    11
# 80.0    11
# 90.0     8
# Name: score, dtype: int64
# Пустых значений:
# 0
# Уникальных значений:
# 12

# %% [markdown]
# # Как заполнять пропуски в зависимости от вероятности выпадения из имеющихся данных?

# %%
#def set_failures(x):
#    i = 1
#    if pd.isnull(x) and i%2==0:
#        i+=1
#        return 2.0
#    if pd.isnull(x) and i%2==1:
#        i+=1
#        return 3.0
#    else:
#        return x

# %%
#students.failures = students.failures.apply(set_failures)
#get_unique_and_isnull(students)

# %% [markdown]
# # Работа с текстовыми переменными

# %% [markdown]
# Просмотрев данные видно, что логические ошибоки/описки отсутствуют, приемлимое количество повторений возможных вариантов, но остается проблема с пропусками данных, на данный момент оставим данные с пропусками и посмотрим, что из этого получится.

# %% [markdown]
# # Анализ данных

# %%
students.corr()
# Out:
#                           age      medu      fedu  traveltime  studytime  \
# age                  1.000000 -0.165792 -0.140104    0.152227   0.027476
# medu                -0.165792  1.000000  0.628736   -0.141653   0.050702
# fedu                -0.140104  0.628736  1.000000   -0.049294  -0.031196
# traveltime           0.152227 -0.141653 -0.049294    1.000000  -0.145064
# studytime            0.027476  0.050702 -0.031196   -0.145064   1.000000
# failures             0.109853 -0.232272 -0.230552    0.046432  -0.155285
# studytime, granular -0.027476 -0.050702  0.031196    0.145064  -1.000000
# famrel              -0.038021  0.021932  0.014040   -0.048189   0.057412
# freetime             0.006051  0.012281  0.016846   -0.051696  -0.087261
# goout                0.177353  0.016731 -0.000356   -0.040444  -0.006896
# health              -0.055798 -0.014774 -0.012161   -0.009388  -0.029986
# absences             0.049140  0.014729 -0.084926    0.010099   0.033685
# score               -0.230566  0.213985  0.089982   -0.082070   0.073544
#
#                      failures  studytime, granular    famrel  freetime  \
# age                  0.109853            -0.027476 -0.038021  0.006051
# medu                -0.232272            -0.050702  0.021932  0.012281
# fedu                -0.230552             0.031196  0.014040  0.016846
# traveltime           0.046432             0.145064 -0.048189 -0.051696
# studytime           -0.155285            -1.000000  0.057412 -0.087261
# failures             1.000000             0.155285 -0.032268  0.039282
# studytime, granular  0.155285             1.000000 -0.057412  0.087261
# famrel              -0.032268            -0.057412  1.000000  0.170935
# freetime             0.039282             0.087261  0.170935  1.000000
# goout                0.010633             0.006896  0.059527  0.245815
# health               0.098418             0.029986  0.101972  0.076897
# absences             0.001480            -0.033685 -0.012875 -0.023688
# score               -0.343732            -0.073544  0.081992  0.016664
#
#                         goout    health  absences     score
# age                  0.177353 -0.055798  0.049140 -0.230566
# medu                 0.016731 -0.014774  0.014729  0.213985
# fedu                -0.000356 -0.012161 -0.084926  0.089982
# traveltime          -0.040444 -0.009388  0.010099 -0.082070
# studytime           -0.006896 -0.029986  0.033685  0.073544
# failures             0.010633  0.098418  0.001480 -0.343732
# studytime, granular  0.006896  0.029986 -0.033685 -0.073544
# famrel               0.059527  0.101972 -0.012875  0.081992
# freetime             0.245815  0.076897 -0.023688  0.016664
# goout                1.000000  0.003833  0.078599 -0.113473
# health               0.003833  1.000000 -0.018970  0.008885
# absences             0.078599 -0.018970  1.000000  0.213539
# score               -0.113473  0.008885  0.213539  1.000000

# %%
sns.heatmap(students.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видно, что колонки 'studytime' и 'studytime, granular' обратно зависимы, удалим колонку с отрицательными значениями.
# Выберем наиболее коррелирующие колонки с результатом, это: 'age', 'medu', 'failures', 'absences'.

# %%
students.drop('studytime, granular', axis = 1, inplace = True)
students
# Out:
#     school sex  age address famsize pstatus  medu  fedu      mjob      fjob  \
# 0       GP   F   18       U     NaN       A   4.0   4.0   at_home   teacher
# 1       GP   F   17       U     GT3     NaN   1.0   1.0   at_home     other
# 2       GP   F   15       U     LE3       T   1.0   1.0   at_home     other
# 3       GP   F   15       U     GT3       T   4.0   2.0    health       NaN
# 4       GP   F   16       U     GT3       T   3.0   3.0     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 383     MS   M   19       R     GT3       T   1.0   1.0     other  services
# 385     MS   F   18       R     GT3       T   2.0   2.0   at_home     other
# 387     MS   F   19       R     GT3       T   2.0   3.0  services     other
# 388     MS   F   18       U     LE3       T   3.0   1.0   teacher  services
# 393     MS   M   18       R     LE3       T   3.0   2.0  services     other
#
#      reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0    course   mother         2.0        2.0       0.0       yes     no   no
# 1    course   father         1.0        2.0       0.0        no    yes   no
# 2     other   mother         1.0        2.0       3.0       yes     no  NaN
# 3      home   mother         1.0        3.0       0.0        no    yes  yes
# 4      home   father         1.0        2.0       0.0        no    yes  yes
# ..      ...      ...         ...        ...       ...       ...    ...  ...
# 383   other   mother         2.0        1.0       1.0        no     no   no
# 385   other      NaN         NaN        3.0       0.0        no     no  yes
# 387  course   mother         1.0        3.0       1.0        no     no   no
# 388  course   mother         1.0        2.0       0.0        no    yes  yes
# 393  course   mother         3.0        1.0       0.0        no     no   no
#
#     activities nursery higher internet romantic  famrel  freetime  goout  \
# 0           no     yes    yes      NaN       no     4.0       3.0    4.0
# 1           no      no    yes      yes       no     5.0       3.0    3.0
# 2           no     yes    yes      yes      NaN     4.0       3.0    2.0
# 3          yes     yes    yes      yes      yes     3.0       2.0    2.0
# 4           no     yes    yes       no       no     4.0       3.0    2.0
# ..         ...     ...    ...      ...      ...     ...       ...    ...
# 383         no     NaN    yes       no       no     4.0       3.0    2.0
# 385         no     yes    yes      NaN       no     5.0       3.0    3.0
# 387        yes      no    yes      yes       no     5.0       4.0    2.0
# 388         no     yes    yes      yes       no     4.0       3.0    4.0
# 393        NaN      no    yes      yes       no     4.0       4.0    1.0
#
#      health  absences  score
# 0       3.0       6.0   30.0
# 1       3.0       4.0   30.0
# 2       3.0      10.0   50.0
# 3       5.0       2.0   75.0
# 4       5.0       4.0   50.0
# ..      ...       ...    ...
# 383     5.0       0.0    0.0
# 385     4.0       2.0   50.0
# 387     5.0       0.0    0.0
# 388     1.0       0.0   40.0
# 393     5.0       0.0   50.0
#
# [271 rows x 29 columns]

# %%
sns.pairplot(students, kind = 'reg')

# %% [markdown]
# Проанализируем номинативные переменные

# %%
for col in ['school', 'sex', 'address', 'famsize', 'pstatus', 'mjob', 'fjob', 'reason', 'guardian', 'schoolsup',
            'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_boxplot(col)

# %% [markdown]
# Используем тест Стьюдента

# %% [markdown]
# # Как изменить функцию get_stat_dif, что бы она применялась без ограничений на минимальное повторение элемента в датафрейме?

# %%
for col in ['school', 'sex', 'address', 'famsize', 'pstatus', 'mjob', 'fjob', 'reason', 'guardian', 'schoolsup',
            'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки paid
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic

# %% [markdown]
# # В результате анализа имеем:

# %%
students_for_model = students.loc[:, ['age', 'medu', 'failures', 'absences','paid', 'higher', 'romantic']]
students_for_model.head()
# Out:
#    age  medu  failures  absences paid higher romantic
# 0   18   4.0       0.0       6.0   no    yes       no
# 1   17   1.0       0.0       4.0   no    yes       no
# 2   15   1.0       3.0      10.0  NaN    yes      NaN
# 3   15   4.0       0.0       2.0  yes    yes      yes
# 4   16   3.0       0.0       4.0  yes    yes       no
